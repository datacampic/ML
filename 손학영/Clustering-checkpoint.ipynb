# %%
import pandas as pd 
import numpy as np

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ## 캐글 참고
# [참고](https://www.kaggle.com/datark1/customers-clustering-k-means-dbscan-and-ap)
#
# ### EDA
#  - 통계치 확인
#  - 결측치 확인
#  - 분포 확인
#     - 성별에 따른 나이 분포 : 히스토그램, Kolgomorov-Smirnov 검정
#     - Kolgomorov-Smirnov 검정이란? 표본을 참조 확률 분포와 비교하거나 두 표본을 비교하는 데에 사용할 수 있는 연속 1차원 확률 분포의 동등성에 대한 비모수 검정
#     - 성별에 따른 소득 분포 : 히스토그램, box plot
#  - 상관성 확인
#    - 나이와 Spending Score
#    - 성별에 따른 나이와 소득 상관성 : 피어슨 상관계수

# %%
df = pd.read_csv('./data/Mall_Customers.csv')
df.head(2)
# Out:
#    CustomerID Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1   Male   19                  15                      39
# 1           2   Male   21                  15                      81

# %%
df.drop('CustomerID', axis = 1, inplace = True)
df.head(2)
# Out:
#   Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0   Male   19                  15                      39
# 1   Male   21                  15                      81

# %%
df.isnull().sum()
# Out:
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
for i in range(df.shape[0]) : 
    if df['Gender'].iloc[i] == 'Male' : 
        df['Gender'].iloc[i] = 0 
    else : 
        df['Gender'].iloc[i] = 1

# %%
df.head(2)
# Out:
#   Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0      0   19                  15                      39
# 1      0   21                  15                      81

# %%
sns.kdeplot(df['Age'])
plt.title('Age')
plt.show()

# %%
fig, axes = plt.subplots(1,3, figsize = (27,9))


sns.distplot(df['Age'], ax =axes[0])
sns.distplot(df['Annual Income (k$)'], ax =axes[1])
sns.distplot(df['Spending Score (1-100)'], ax =axes[2])

axes[0].set_title('Age')
axes[1].set_title('Income')
axes[2].set_title('Score')


plt.title('분포도')
plt.show()

# %%
# 표준화 
# from sklearn.preprocessing import StandardScaler
# 정규화
from sklearn.preprocessing import MinMaxScaler

# scaler = StandardScaler()
scaler = MinMaxScaler()

df_scaled = pd.DataFrame(scaler.fit_transform(df), columns = df.columns)
df_scaled.head()
# Out:
#    Gender       Age  Annual Income (k$)  Spending Score (1-100)
# 0     0.0  0.019231            0.000000                0.387755
# 1     0.0  0.057692            0.000000                0.816327
# 2     1.0  0.038462            0.008197                0.051020
# 3     1.0  0.096154            0.008197                0.775510
# 4     1.0  0.250000            0.016393                0.397959

# %%
fig, axes = plt.subplots(1,3, figsize = (27,9))


sns.distplot(df_scaled['Age'], ax =axes[0])
sns.distplot(df_scaled['Annual Income (k$)'], ax =axes[1])
sns.distplot(df_scaled['Spending Score (1-100)'], ax =axes[2])

axes[0].set_title('Age')
axes[1].set_title('Income')
axes[2].set_title('Score')


plt.title('분포도')
plt.show()

# %% [markdown]
# # 1. K-means
# > 파라미터
#  - 클러스터의 수
#
# > 사용 케이스
#  - 일반적인 목적
#  - 고른 클러스터의 사이즈
#  - 클러스터가 별로 없을 때
#
# > 클러스터 기준
#  - 점들 간의 거리
#
# > 사용 방법
#  1) 군집의 개수 k 설정
#     **설정하는 방법**
#     - Rule of Thumb : 경험 법칙
#     - Elbow Method : Cluster 간의 거리의 합을 나타내는 `inertia`가 급격히 떨어지는 구간의 K 값
#     - 정보 기준 접근법 :
#  2) 초기 centroid 설정
#     **설정하는 방법**
#     - Randomly Select
#     - Manually assign
#     - `K-means+`+ : k-means의 문제점 (중심점 무작위 선정) 해결
#         1) 가지고 있는 데이터 포인트 중에서 무작위로 1개를 선택하여 첫 번째 중심점으로 지정
#         2) 나머지 데이터 포인트들에 대해 그 **첫 번째 중심점까지의 거리 계산**
#         3) 이미 지정된 중심점으로부터 **최대한 먼 곳에 배치된 데이터포인트**를 그 다음 중심점으로 지정
#         4) 중심점이 k개가 될 때가지 2,3번 반복
#  3) 데이터를 군집에 할당 : 거리 상 가장 가까운 centroid(군집)으로 할당
#  4) 중심점 재설정(갱신) : 군집에 속하는 데이터들의 가장 중간(평균)에 위치한 지점을 갱신
#  5) 데이터를 군집에 재할당(배정)
#  6) 4,5 번을 중심점의 위치가 더이상 변하지 않을 때까지 반복

# %% [markdown]
# ### 사용 : K-means++

# %%
# K-means++ 모델 생성 
from sklearn.cluster import KMeans
k = 8
model = KMeans(n_clusters=k, init= 'k-means++') # 전통적인 k-means는 중심정을 랜덤하게 하기에 init = 'random' 사용

# %%
# 모델 실행 
y = model.fit_predict(df_scaled)
df_scaled['cluster'] = y
df_scaled.head(2)
# Out:
#    Gender       Age  Annual Income (k$)  Spending Score (1-100)  cluster
# 0     0.0  0.019231                 0.0                0.387755        3
# 1     0.0  0.057692                 0.0                0.816327        0

# %%
plt.figure(figsize=(10,10))

for i in range(k):
    plt.scatter(df_scaled.loc[df_scaled['cluster'] == i, 'Annual Income (k$)'], df_scaled.loc[df_scaled['cluster'] == i, 'Spending Score (1-100)'], 
                label = 'cluster ' + str(i))

plt.legend()
plt.title('K = %d results'%k , size = 15)
plt.xlabel('Annual Income', size = 12)
plt.ylabel('Spending Score', size = 12)
plt.show()

# %%
df_scaled
# Out:
#      Gender       Age  Annual Income (k$)  Spending Score (1-100)  cluster
# 0       0.0  0.019231            0.000000                0.387755        1
# 1       0.0  0.057692            0.000000                0.816327        1
# 2       0.0  0.038462            0.008197                0.051020        0
# 3       0.0  0.096154            0.008197                0.775510        1
# 4       0.0  0.250000            0.016393                0.397959        1
# ..      ...       ...                 ...                     ...      ...
# 195     0.0  0.326923            0.860656                0.795918        1
# 196     0.0  0.519231            0.909836                0.275510        0
# 197     0.0  0.269231            0.909836                0.744898        1
# 198     0.0  0.269231            1.000000                0.173469        0
# 199     0.0  0.230769            1.000000                0.836735        1
#
# [200 rows x 5 columns]

# %%
df_scaled.head()
# Out:
#    Gender       Age  Annual Income (k$)  Spending Score (1-100)  cluster
# 0     0.0  0.019231            0.000000                0.387755        1
# 1     0.0  0.057692            0.000000                0.816327        4
# 2     0.0  0.038462            0.008197                0.051020        1
# 3     0.0  0.096154            0.008197                0.775510        4
# 4     0.0  0.250000            0.016393                0.397959        1

# %%
# 한 번에 하기 
fig = plt.figure(figsize= (30,10))

ax = fig.add_subplot(1, 5, 1, projection='3d')

for k in range(3,8) : 
    # 모델 생성 
    model = KMeans(n_clusters= k, 
    # init = 'k-means++', 
    random_state = 10)

    # 모델 실행 
    y = model.fit_predict(df_scaled.drop('cluster', axis = 1))
    df_scaled['cluster'] = y
    
    ax = fig.add_subplot(1, 5, k-2, projection='3d')

    # plt.subplot(1,k-3,k-3)
    for i in range(k) : 
        ax.scatter(df_scaled.loc[df_scaled['cluster'] == i, 'Age'], df_scaled.loc[df_scaled['cluster'] == i, 'Annual Income (k$)'], df_scaled.loc[df_scaled['cluster'] == i, 'Spending Score (1-100)'], 
                label = 'cluster ' + str(i), alpha = 0.5, 
                s = 50) # s 데이터 포인트  크기 
    
    ax.set_title(f'k={k}')

# plt.legend()
plt.show()

# %% [markdown]
# ## 더 해보면 좋을 것
#
# - feature selection 후 시각화
#
# <hr>
# <hr>

# %% [markdown]
# # Dendrogram
# > 계층적 클러스터링

# %% [markdown]
# # DBSCAN
# > 밀도기반 클러스터링

# %% [markdown]
# # Affinity propagation
# > Affinity propagation란?
#  - 데이터에 대한 설명을 거의 듣지를 못해서, 진짜로 데이터 구조를 탐험부터 해야 하는 상황에서 사용하는 기법
#  - 모든 데이터가 특정한 기준에 따라 자신을 대표할 대표 데이터를 선택한다. 만약 스스로가 자기 자신을 대표하게 되면 클러스터의 중심이 된다.
#
#
# > 파라미터
#  - damping, sample preference
#
# > K-means와 공통점 및 차이점
# - 공통점
#  - 두 알고리즘 모두 클러스터 형태가 둥글어야 하는(globular) 가정이 있습니다.
#  - k-means의 변형인 k-medoids와 동일하게 cluster center를 data point 자체(exemplar)를 사용합니다. 참고로 k-means는 클러스터에 속한 멤버의 평균값을 cluster center로 합니다.
# - 차이점
#  - AP는 k-means와 다르게 클러스터의 개수 k를 지정할 필요가 없습니다.
#  - AP는 k-means와 다르게 클러스터들이 공간을 동일한 크기로 분할하는 것을 강요하지 않습니다. 참고: Visualizing the stock market structure
